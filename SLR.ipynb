# %% [markdown]
# <a href="https://colab.research.google.com/github/asepmuhidin/DM-22-C5/blob/main/SLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediksi Jenis kelamin berdasarkan Tinggi dan Berat menggunakan model Simple Linear Regression

# %% [markdown]
# ## Loading Dataset

# %%
import pandas as pd
fdata='https://raw.githubusercontent.com/asepmuhidin/MK-Data-Mining-UPB/main/dataset/weight-height.csv'
df=pd.read_csv(fdata)
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Cek Duplikasi Data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Cek Data kosong / null value

# %%
df.isna().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# dtype: int64

# %% [markdown]
# ## Split Fitur dan label Dataset

# %%
y=df.Gender.apply(lambda x:0 if x=='Male' else 1 )
X=df[['Height','Weight']]

X.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Gender, dtype: int64
